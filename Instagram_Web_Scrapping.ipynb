# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from time import sleep
import os
import requests
import shutil

# %%
class App:
    def __init__(self,username = 'arham8834',password = 'projct_@123',target_username = 'arham8834',path  = 'C:/Users/Lenovo/Desktop/scrap'):
        
        self.username = username
        self.password = password
        self.target_username = target_username
        self.path = path
        self.driver = webdriver.Chrome('C:/Users/Lenovo/Downloads/chromedriver_win32/chromedriver')
        self.main_url = 'https://www.instagram.com'
        self.driver.get(self.main_url)
        sleep(5)
        
        self.log_in()
        sleep(5)
        self.close_dialog_box()
        sleep(2)
        self.close_notification()
        sleep(3)
        self.open_target_profile()
        sleep(3)
        self.scroll_down()
        sleep(3)
        self.download_img()
        sleep(3)
        #self.driver.close()
        
    def log_in(self):
        login_input = self.driver.find_element_by_xpath('//input[@name = "username"]')
        login_input.send_keys(self.username)
        
        password_input = self.driver.find_element_by_xpath('//input[@name = "password"]')
        password_input.send_keys(self.password)
        
        #login_button = self.driver.find_element_by_link_text('Log In')
        #self.login_button.click()
    
        password_input.submit()
        #input('stop for now')
        
    def close_dialog_box(self):
        try:
            sleep(1)
            close_btn = self.driver.find_element_by_xpath('//button[@class = "sqdOP yWX7d    y3zKF     "]')
            close_btn.click()
            sleep(1)
        except Exception as e:
            pass
        
    def close_notification(self):
        try:
            sleep(1)
            close_btn = self.driver.find_element_by_xpath('//button[@class = "aOOlW   HoLwm "]')
            close_btn.click()
            sleep(1)
            
        except Exception as e:
            pass
        
    def open_target_profile(self):
        self.search_bar = self.driver.find_element_by_xpath('//input[@class = "XTCLo x3qfX "]')
        self.search_bar.send_keys(self.target_username)
        target_profile_url = 'https://www.instagram.com/dataminer2060/'
        self.driver.get(target_profile_url)
        sleep(3)
    
    def scroll_down(self):
        post_count = self.driver.find_element_by_xpath('//span[@class = "g47SY "]')
        post_count = str(post_count.text).replace(',','') # 15,486==> 15486
        self.post_count = int(post_count)
        if(self.post_count > 12):
            no_of_scrolls = int(self.post_count) + 3
            
            for value in range(no_of_scrolls):
                #print(value)
                self.driver.execute_script('window.scrollTo(0,document.body.scrollHeight);')
                sleep(1)
        
    def download_img(self):
        
        soup = BeautifulSoup(self.driver.page_source,'lxml')
        all_images= soup.find_all('img')
        print("Length of image",len(all_images))
        
        for index,image in enumerate(all_images): ## numbers from 0 and so on
            filename = 'image_' +str(index) +'.jpg'
            image_path = os.path.join(self.path,filename)
            link = image['src']
            print('Downloading image',index)
            response = requests.get(link,stream = True)
            try:
                with open(image_path,'wb') as file:
                    shutil.copyfileobj(response.raw,file)
                    
            except Exception as e:
                print(e)
                print('Could Not print image number',index)
                print('Image Link',link)
                    
                
            
        
        
        
if __name__ == '__main__':
    app = App()
# Out:
# Length of image 31
# ...
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# <ipython-input-65-c4112886d85b> in <module>
#     103
#     104 if __name__ == '__main__':
# --> 105     app = App()
#
# <ipython-input-65-c4112886d85b> in __init__(self, username, password, target_username, path)
#      21         self.scroll_down()
#      22         sleep(3)
# ---> 23         self.download_img()
#      24         sleep(3)
#      25         #self.driver.close()
#
# <ipython-input-65-c4112886d85b> in download_img(self)
#      87             link = image['src']
#      88             print('Downloading image',index)
# ---> 89             response = requests.get(link,stream = True)
#      90             try:
#      91                 with open(image_path,'wb') as file:
#
# ~\AppData\Roaming\Python\Python37\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
# ...
